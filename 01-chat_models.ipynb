# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Carregar variáveis de ambiente
load_dotenv()
chat = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key = os.getenv("ROUTER_API"),
    model="gpt-oss-120b:free", 
    temperature=0.7
)

# %% [markdown]
# ### Trabalhando com LLMs e ChatModels no LangChain
# - O LangChain fornece uma interface padronizada para conectar diferentes Modelos de Linguagem (LLMs).
# - Hoje a forma recomendada é trabalhar com **ChatModels**, que suportam tanto prompts simples quanto interações mais complexas baseadas em mensagens.

# %% [markdown]
# ### Exemplo 1 - Prompt Simples
# - Usando apenas texto, sem mensagens estruturadas

# %%
resposta = chat.invoke("Me conte uma piada curta sobre programadores.")
print(resposta.content)
# Out:
# Por que o programador foi ao médico?
#
# Porque ele tinha um *bug* no *código* e não conseguia *debugar* a dor!

# %% [markdown]
# ### Exemplo 2 - Resposta em Streaming

# %%
prompt = "Escreva uma história de aventura em 3 parágrafos, com cliffhangers."
for chunk in chat.stream(prompt):
    print(chunk.content, end="", flush=True)
# Out:
# Nas profundezas da floresta de Miraluz, a jovem cartógrafa Lúcia encontrou um antigo pergaminho que descrevia a localização de um templo perdido, onde, segundo a lenda, repousava o Coração de Estrela – um cristal capaz de controlar a própria luz. Decidida a provar sua coragem e desvendar os mistérios que há séculos afligiam seu vilarejo, ela reuniu um grupo improvável: o ex‑batedor de caçadores de sombras, um velho druida cego e um ladrão de sombras que só falava em enigmas. Enquanto avançavam entre árvores que sussurravam segredos, o céu escureceu repentinamente, e um rugido distante fez o chão tremer sob seus pés, revelando uma fenda colossal que parecia levar ao próprio coração da terra…
#
# Sem hesitar, Lúcia liderou o grupo pela abertura, descendo por corredores de pedra cobertos por musgo luminescente que pulsava como se estivesse vivo. Cada passo ecoava como um tambor, e nas paredes surgiam inscrições que mudavam de forma, mostrando visões de um passado que nunca viveram. Quando chegaram a uma câmara onde o ar era tão denso que parecia sólido, encontraram um altar de obsidiana sobre o qual repousava o Coração de Estrela, mas antes que pudessem tocá‑lo, uma sombra colossal emergiu das profundezas, tomando a forma de um dragão de cristal quebrado que sussurrou: “Você ousa roubar o que nunca foi seu?” – e então, com um movimento rápido, agarrou o cristal e desapareceu num clarão ofuscante.
#
# Desesperada, Lúcia agarrou a mão do ladrão de sombras, que revelou que o dragão não era inimigo, mas guardião de um segredo ainda maior: o Coração de Estrela era apenas a chave para abrir um portal que levaria a um mundo onde o tempo se desfaz. O druida, com um brilho inesperado surgindo em seus olhos cegos, começou a cantar um antigo cântico que fez as paredes vibrarem, e a fenda ao fundo da câmara começou a se fechar, sugando tudo em seu interior. No último instante, Lúcia ouviu um eco distante que dizia: “Se você quiser salvar seu mundo, deve escolher entre o futuro que conhece ou o passado que ainda não escreveu…” E então, o chão tremeu novamente, pronto para engolir tudo…

# %% [markdown]
# ### Exemplo 3 – Batch
# - Enviando várias perguntas de uma vez

# %%
perguntas = [
    "O que é Memória RAM?",
    "Explique o papel da Memória Cache.",
    "Qual a função do Processador?"
]
respostas = chat.batch(perguntas)

for pergunta, resposta in zip(perguntas, respostas):
    print(f"\n❓ {pergunta}")
    print(f"💡 {resposta.content}")
# Out:
# ❓ O que é Memória RAM?
# 💡 **Memória RAM (Random Access Memory)** é um tipo de memória volátil utilizada pelos computadores e outros dispositivos eletrônicos para armazenar temporariamente os dados e instruções que o processador precisa acessar rapidamente enquanto o sistema está em operação.
#
# ### Principais características da RAM
#
# | Característica | Descrição |
# |----------------|-----------|
# | **Volatilidade** | Quando o dispositivo é desligado, todo o conteúdo da RAM é perdido. |
# | **Acesso aleatório** | Qualquer posição de memória pode ser lida ou escrita em tempo constante, independentemente da sua localização. |
# | **Velocidade** | Muito mais rápida que dispositivos de armazenamento permanente (HD, SSD, etc.). |
# | **Capacidade** | Medida em gigabytes (GB) ou terabytes (TB) em sistemas modernos. |
# | **Tipos** | DDR, DDR2, DDR3, DDR4, DDR5 (e suas variantes de baixa voltagem, como LPDDR para dispositivos móveis). |
#
# ### Como a RAM funciona no dia a dia
#
# 1. **Carregamento de programas** – Quando você abre um aplicativo, o sistema operacional copia os arquivos executáveis e os dados necessários do disco rígido/SSD para a RAM. Isso permite que o processador acesse essas informações rapidamente.
# 2. **Execução de processos** – Cada processo em execução tem seu próprio espaço na RAM, onde são armazenadas variáveis, pilhas de chamadas e buffers temporários.
# 3. **Cache de dados** – Navegadores, editores de texto e outros programas mantêm partes de arquivos ou páginas da web na RAM para acelerar o acesso subsequente.
# 4. **Multitarefa** – Quanto mais RAM disponível, mais programas podem permanecer abertos simultaneamente sem que o sistema comece a usar a memória virtual (swap), que é muito mais lenta.
#
# ### Diferença entre RAM e armazenamento permanente
#
# | RAM | Armazenamento permanente (HD/SSD) |
# |-----|-----------------------------------|
# | Volátil (apaga ao desligar) | Não volátil (mantém dados após desligar) |
# | Muito rápida (nanosegundos) | Mais lenta (milissegundos) |
# | Usada para dados “em uso” | Usada para guardar arquivos, sistema operacional, etc. |
# | Custo por GB geralmente maior | Custo por GB geralmente menor |
#
# ### Tipos mais comuns de RAM hoje
#
# | Tipo | Velocidade típica (MT/s) | Uso típico |
# |------|--------------------------|------------|
# | DDR4 | 2133–3200 | Desktops, laptops modernos |
# | DDR5 | 4800–6400 | PCs de alto desempenho, laptops premium (a partir de 2022) |
# | LPDDR4/LPDDR5 | 3200–6400 | Smartphones, tablets, notebooks ultrafinos |
# | DDR3 | 1066–2133 | Sistemas legados (ainda em uso em alguns PCs antigos) |
#
# ### Por que a quantidade de RAM importa?
#
# - **Performance geral:** Insuficiência de RAM força o sistema a usar a memória virtual (swap), que é muito mais lenta e causa travamentos ou lentidão.
# - **Multitarefa:** Mais RAM permite abrir mais aplicativos ao mesmo tempo e trabalhar com arquivos grandes (ex.: edição de vídeo, modelagem 3D).
# - **Jogos e aplicações intensivas:** Jogos modernos e softwares de renderização podem exigir 16 GB ou mais para rodar suavemente.
#
# ### Dicas para escolher a RAM certa
#
# 1. **Verifique a compatibilidade da placa‑mãe:** Tipo (DDR4/DDR5), frequência suportada e número máximo de módulos.
# 2. **Considere a latência (CL):** Menor número de ciclos de latência pode melhorar o desempenho em algumas situações.
# 3. **Opte por módulos dual‑channel:** Instalar pares de módulos de mesma capacidade e frequência habilita o modo de canal duplo, dobrando a largura de banda efetiva.
# 4. **Planeje o futuro:** Se o orçamento permitir, escolha uma capacidade que supra as necessidades dos próximos anos (ex.: 16 GB ou 32 GB para uso geral e jogos).
#
# ---
#
# **Resumindo:** a memória RAM é o “espaço de trabalho” temporário do seu computador, onde dados e instruções são mantidos enquanto o processador os utiliza. É rápida, volátil e essencial para que o sistema opere de forma fluida. Quanto mais RAM (e melhor compatível) você tiver, mais suave será a experiência ao usar múltiplos programas ou tarefas exigentes.
#
# ❓ Explique o papel da Memória Cache.
# 💡 **Memória Cache: o que é e por que ela é tão importante?**
#
# ---
#
# ## 1. Visão geral
# A memória cache (ou simplesmente **cache**) é um tipo especial de memória volátil, muito rápida, que fica inserida entre o **processador (CPU)** e a **memória principal (RAM)**. Seu objetivo principal é reduzir o tempo que o processador leva para obter os dados e instruções de que precisa para executar programas.
#
# > **Analogia:** imagine que o processador é um chef de cozinha muito rápido, a RAM é a despensa da cozinha e a cache é a bancada de trabalho onde o chef deixa os ingredientes que usa com mais frequência. Sempre que o chef precisa de algo que está na bancada, ele o pega instantaneamente; se precisar de algo que está só na despensa, leva mais tempo para ir buscar.
#
# ---
#
# ## 2. Por que a CPU precisa de cache?
# 1. **Descompasso de velocidade (CPU vs. RAM)**
#    - **CPU:** GHz (bilhões de ciclos por segundo).
#    - **RAM:** latência de dezenas a centenas de ciclos.
#    - **Cache:** latência de 1‑5 ciclos.
#
#    Sem cache, a CPU ficaria “esperando” a RAM em grande parte do tempo, o que desperdiçaria seu potencial de processamento.
#
# 2. **Padrões de acesso à memória**
#    - **Localidade temporal:** se um dado foi acessado recentemente, há alta probabilidade de que seja acessado novamente em breve.
#    - **Localidade espacial:** se um endereço de memória foi acessado, é provável que endereços vizinhos sejam acessados em seguida.
#
#    A cache explora esses padrões armazenando blocos de dados/instruções que já foram usados (temporal) e os vizinhos desses blocos (espacial).
#
# ---
#
# ## 3. Estrutura típica da hierarquia de memória
#
# ```
# CPU  <--->  L1 Cache (≈ 32‑64 KB, muito rápida)  <--->
#            L2 Cache (≈ 256 KB‑2 MB, ainda rápida)  <--->
#            L3 Cache (≈ 2‑32 MB, compartilhada entre núcleos)  <--->
#            RAM (≈ GB, latência maior)  <--->
#            Disco/SSD (armazenamento permanente, muito mais lenta)
# ```
#
# - **L1**: normalmente dividido em *L1‑i* (instruções) e *L1‑d* (dados). É a mais próxima da ALU e tem a menor latência.
# - **L2**: pode ser dedicada a cada núcleo ou compartilhada por poucos núcleos; serve como “buffer” entre L1 e L3.
# - **L3**: geralmente compartilhada por todos os núcleos de um mesmo chip; é maior, porém um pouco mais lenta que L2.
# - **Memória principal (RAM)**: onde residem os programas e dados completos, mas com acesso mais lento.
#
# ---
#
# ## 4. Como a cache funciona (conceitos básicos)
#
# ### 4.1. Mapeamento
# - **Cache line / bloco**: unidade mínima que a cache armazena (geralmente 64 bytes).
# - **Endereçamento**: o endereço de memória é dividido em:
#   - **Tag** – identifica qual bloco da memória está armazenado.
#   - **Índice** – aponta para a “linha” ou “conjunto” da cache.
#   - **Offset** – indica a posição dentro da linha (os 64 bytes).
#
# ### 4.2. Políticas de substituição
# Quando a cache está cheia e precisa de espaço para um novo bloco, decide qual bloco antigo será descartado:
# - **LRU (Least Recently Used)** – substitui o bloco menos usado recentemente.
# - **FIFO (First‑In, First‑Out)** – substitui o bloco que está na cache há mais tempo.
# - **Random** – escolhe aleatoriamente; simples, porém menos eficiente.
#
# ### 4.3. Consistência (coerência) em sistemas multicore
# Em processadores com múltiplos núcleos, cada núcleo tem sua própria hierarquia de cache. Para garantir que todos vejam o mesmo valor de uma variável, protocolos como **MESI (Modified, Exclusive, Shared, Invalid)** são usados para sincronizar as cópias de linhas de cache entre os núcleos.
#
# ---
#
# ## 5. Benefícios práticos da cache
#
# | Benefício | Impacto no desempenho |
# |-----------|-----------------------|
# | **Redução de latência** | Acesso a dados em ~1‑5 ciclos vs. 50‑200 ciclos da RAM. |
# | **Aumento da taxa de instruções por ciclo (IPC)** | Mais instruções podem ser executadas sem stalls. |
# | **Economia de energia** | Menos acessos à RAM (que consome mais energia). |
# | **Melhoria em workloads com alta localidade** | Jogos, compiladores, bancos de dados, algoritmos de machine learning, etc. |
#
# ---
#
# ## 6. Exemplos de uso no dia a dia
#
# 1. **Navegadores web** – armazenam partes de páginas (HTML, CSS, imagens) na cache para carregamento instantâneo ao voltar a visitar o site.
# 2. **Compiladores** – mantêm tabelas de símbolos e código gerado em cache, acelerando recompilações incrementais.
# 3. **Processamento de vídeo** – frames vizinhos são mantidos na cache, permitindo decodificação mais rápida.
#
# ---
#
# ## 7. Limitações e armadilhas
#
# - **Cache miss**: quando o dado requisitado não está na cache. Existem três tipos:
#   - **Cold (compulsory) miss** – primeira vez que o bloco é acessado.
#   - **Capacity miss** – a cache é pequena demais para conter todo o conjunto de dados ativo.
#   - **Conflict miss** – ocorre em caches associativas quando múltiplos blocos competem pelo mesmo conjunto.
# - **Cache thrashing**: padrão de acesso que faz a cache ficar constantemente trocando blocos, degradando o desempenho.
# - **Coerência**: em sistemas multicore, falhas de sincronização podem levar a bugs difíceis de depurar (ex.: “data race”).
#
# ---
#
# ## 8. Tendências e inovações
#
# - **Cache de nível L4**: alguns processadores Intel Xeon introduziram uma L4 (eDRAM) para melhorar a capacidade de cache sem aumentar a latência significativamente.
# - **Cache não volátil (NVCache)**: uso de memória não volátil (ex.: Intel Optane) como camada de cache entre RAM e armazenamento permanente.
# - **Cache inteligente / prefetching avançado**: algoritmos de aprendizado de máquina que preveem quais blocos serão necessários antes mesmo de serem requisitados.
# - **Arquiteturas heterogêneas**: GPUs, TPUs e accelerators têm seus próprios caches otimizados para acesso de matriz e fluxo de dados.
#
# ---
#
# ## 9. Resumo rápido
#
# - **O que é:** memória ultra‑rápida entre a CPU e a RAM.
# - **Por que existe:** elimina o gargalo de latência entre CPU (gigahertz) e RAM (nanosegundos).
# - **Como funciona:** armazena linhas de memória usando políticas de mapeamento e substituição; explora localidade temporal e espacial.
# - **Impacto:** aumenta a velocidade de execução, a eficiência energética e a taxa de instruções por ciclo.
# - **Desafios:** misses, thrashing, coerência em ambientes multicore.
#
# Em essência, a **memória cache** é o “atalho” que permite ao processador acessar rapidamente os dados mais relevantes, mantendo o fluxo de instruções tão veloz quanto o próprio hardware pode oferecer. Sem ela, a CPU passaria a maior parte do tempo “esperando” a RAM, e o desempenho dos computadores modernos seria drasticamente menor.
#
# ❓ Qual a função do Processador?
# 💡 O processador – também chamado de **CPU (Unidade Central de Processamento)** – é o “cérebro” de um computador ou de qualquer dispositivo eletrônico que execute software. Sua função principal é **executar instruções** e **gerenciar o fluxo de dados** dentro do sistema.
#
# ### Principais responsabilidades da CPU
#
# | Função | O que acontece | Por que é importante |
# |--------|----------------|----------------------|
# | **Busca (Fetch)** | Recupera a próxima instrução da memória (RAM) usando o **contador de programa (PC)**. | Determina qual operação será realizada a seguir. |
# | **Decodificação (Decode)** | Interpreta a instrução recuperada, identificando a operação (aritmética, lógica, controle, etc.) e os operandos envolvidos. | Converte o código binário em sinais de controle que acionam os circuitos internos. |
# | **Execução (Execute)** | Realiza a operação solicitada: cálculos aritméticos, operações lógicas, movimentação de dados, etc., usando a **ALU (Unidade Lógica e Aritmética)** e outros blocos internos. | Produz o resultado da instrução. |
# | **Acesso à memória (Memory Access)** | Se a instrução requer leitura ou escrita na memória, a CPU controla o acesso ao barramento de dados e à memória RAM ou cache. | Permite ler dados de entrada ou armazenar resultados. |
# | **Write‑back** | O resultado da execução é escrito de volta em registradores internos ou na memória principal. | Atualiza o estado do programa para as próximas instruções. |
# | **Gerenciamento de interrupções** | Detecta sinais externos (teclado, mouse, rede, etc.) e muda temporariamente o fluxo de execução para atender a esses eventos. | Garante resposta rápida a eventos assíncronos. |
# | **Controle de fluxo** | Executa instruções de salto, chamada de subrotinas e retorno, alterando o PC conforme necessário. | Permite a implementação de loops, condições e funções. |
#
# ### Componentes internos que permitem essas funções
#
# 1. **Registradores** – pequenas áreas de armazenamento ultra‑rápidas dentro da CPU (ex.: acumulador, registrador de instrução, registradores de propósito geral).
# 2. **ALU (Unidade Lógica e Aritmética)** – realiza operações matemáticas (soma, subtração, multiplicação) e lógicas (AND, OR, NOT).
# 3. **Control Unit (Unidade de Controle)** – gera sinais de controle que coordenam o movimento de dados entre registradores, ALU, memória e dispositivos de I/O.
# 4. **Cache** – memória de acesso extremamente rápido (L1, L2, L3) que armazena instruções e dados usados com frequência, reduzindo a latência de acesso à RAM.
# 5. **Barras (buses)** – caminhos elétricos que transportam dados, endereços e sinais de controle entre a CPU, memória e periféricos.
#
# ### Resumindo
#
# A função do processador é **interpretar e executar as instruções de um programa**, manipulando dados e controlando o fluxo de informações entre todos os componentes do sistema. Sem ele, o hardware seria apenas um conjunto de circuitos passivos; com ele, o dispositivo pode realizar cálculos, exibir gráficos, rodar jogos, processar textos, conectar à internet e praticamente tudo o que hoje chamamos de “computação”.

# %% [markdown]
# ### Exemplo 4 – Chat estruturado
# - Usando mensagens de sistema e humano para controlar o estilo da resposta

# %% [markdown]
# ### Mensagens no LangChain
# - SystemMessage define o “papel” ou tom do modelo.
# - HumanMessage representa entradas do usuário.
# - AIMessage pode ser usado para simular histórico de conversas.

# %%
from langchain_core.messages import HumanMessage, SystemMessage

# %%
mensagens = [
    SystemMessage(content="Você é um professor de tecnologia que responde com humor."),
    HumanMessage(content="Explique a diferença entre HD e SSD.")
]

resposta = chat.invoke(mensagens)
print(resposta.content)
# Out:
# ### HD vs. SSD: a batalha dos “discos” (com pitadas de humor de professor)
#
# | **Critério** | **HD (Hard Disk Drive)** | **SSD (Solid State Drive)** |
# |--------------|--------------------------|-----------------------------|
# | **Como funciona** | Um prato de metal gira a milhares de RPM e uma cabeça de leitura/escrita “voa” sobre ele, tipo um DJ de 1970 tentando achar a música certa no vinil. | Não tem partes móveis; os dados ficam em chips de memória flash, como se fosse um armário de arquivos digitais que abre instantaneamente. |
# | **Velocidade** | Leitura/escrita tipicamente 80‑150 MB/s. Boa para quem tem paciência (ou para quem ainda acha que “a espera faz parte do charme”). | Leitura/escrita de 500‑3 500 MB/s (ou mais). É a diferença entre “esperar o ônibus” e “pular a fila do metrô”. |
# | **Ruído** | Faz barulho de “zun‑zun‑zun” quando está trabalhando – ótimo para assustar gatos e vizinhos curiosos. | Silencioso como um ninja. Só o ventilador do PC pode ser ouvido (se houver). |
# | **Consumo de energia** | Consome mais energia porque tem motor elétrico. Ideal para quem quer pagar a conta de luz “no conforto da sua cama”. | Muito mais econômico; prolonga a bateria de notebooks como se fosse um elixir mágico. |
# | **Durabilidade física** | Sensível a choques e vibrações – se o laptop cair, o prato pode “bater” e a cabeça pode “raspar”. | Resistente a quedas (até certo ponto). Sem peças móveis, a chance de “cair e quebrar” é bem menor. |
# | **Preço por GB** | Barato. Você pode comprar 4 TB por um preço que ainda cabe no seu orçamento de estudante. | Mais caro. Um SSD de 1 TB ainda pesa mais no bolso, mas vale cada centavo se você não gosta de esperar. |
# | **Capacidade típica** | 1 TB‑8 TB (e ainda mais, se você for colecionador de filmes). | 256 GB‑4 TB (os gigantes já existem, mas custam uma fortuna). |
# | **Instalação** | Precisa de um conector SATA e, às vezes, de espaço extra no gabinete. | Também usa SATA ou NVMe (PCIe); o NVMe é como “plug‑and‑play” de alta velocidade. |
# | **Vida útil (escritas)** | Praticamente ilimitada em termos de ciclos de escrita (até o motor falhar). | Tem um número finito de ciclos de escrita (TBW – Terabytes Written), mas para uso normal isso dura mais que a maioria das carreiras. |
#
# ---
#
# ## 🎓 Resumindo como um professor (com humor)
#
# - **HD**: “É como um disco de vinil antigo. Ele gira, faz barulho, pode pular se você o sacudir, mas ainda assim toca a música (ou abre o arquivo) de vez em quando. É barato, mas você precisa ter paciência para esperar a agulha encontrar a trilha certa.”
#
# - **SSD**: “É como um streaming instantâneo. Não há prato girando nem agulha, tudo acontece na velocidade da luz. Você paga mais, mas nunca mais vai ouvir aquele ‘clack‑clack‑clack’ de um disco tentando encontrar o seu documento.”
#
# ### Quando escolher qual?
#
# - **Se o seu orçamento está apertado** e você tem muito espaço para armazenar arquivos grandes (filmes, backups, jogos que não jogará todo dia), um **HD** ainda faz o serviço. Só não reclame se o Windows demorar a iniciar.
#
# - **Se você quer velocidade, silêncio e bateria duradoura**, vá de **SSD**. É o “café expresso” dos armazenamentos: rápido, forte e deixa todo mundo acordado (ou, melhor, todo mundo produtivo).
#
# ---
#
# ### Dica de “professor de tecnologia” 👨‍🏫
#
# > **Regra dos 2‑1:**
# > - **2 partes** de SSD para o sistema operacional e programas que você usa com frequência.
# > - **1 parte** de HD (ou outro SSD grande) para arquivos estáticos: fotos, vídeos, backups.
#
# Assim você tem o melhor dos dois mundos: rapidez nas tarefas do dia‑a‑dia e espaço de sobra para a sua coleção de memes.
#
# E lembre‑se: **um SSD não vai fazer seu processador correr mais rápido**, mas vai impedir que ele fique “pensando” enquanto o HD ainda está “girando o disco”. Boa escolha e que os bytes estejam sempre a seu favor! 🚀
