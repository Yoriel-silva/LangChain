# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# Carregar variáveis de ambiente
load_dotenv()
chat = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key = os.getenv("ROUTER_API"),
    model="gpt-oss-120b:free", 
    temperature=0.7
)

# %% [markdown]
#  ### O Poder da Composição com LCEL

# %% [markdown]
# #### LCEL permite que você aninhe e combine cadeias de forma elegante.
# - **`RunnablePassthrough`:** Passa a entrada para a próxima etapa sem modificação. Útil para reencaminhar dados.
# - **`RunnablePassthrough.assign()`:** Cria novas chaves no dicionário de entrada, permitindo que a saída de uma mini-cadeia seja usada em prompts futuros.
# - **Funções Python como Runnable:** Você pode transformar qualquer função Python em um `Runnable` com `RunnableLambda` (ou simplesmente usando `|` diretamente, o LangChain converte a função automaticamente).

# %%
# Cadeia para extrair o sentimento
parser = StrOutputParser()
prompt_sentimento = ChatPromptTemplate.from_template("Analise o seguinte feedback e diga se o sentimento é 'positivo', 'negativo' ou 'neutro': {feedback}")
chain_sentimento = prompt_sentimento | chat | parser

print(chain_sentimento)
# Out:
# first=ChatPromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, template="Analise o seguinte feedback e diga se o sentimento é 'positivo', 'negativo' ou 'neutro': {feedback}"), additional_kwargs={})]) middle=[ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x00000229EF4BB620>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000229EF8101A0>, root_client=<openai.OpenAI object at 0x00000229EF002BA0>, root_async_client=<openai.AsyncOpenAI object at 0x00000229EF4BBE00>, model_name='gpt-oss-120b:free', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://openrouter.ai/api/v1', openai_proxy=None)] last=StrOutputParser()

# %%
# Cadeia para extrair o nome do produto
prompt_produto = ChatPromptTemplate.from_template("Qual o nome do produto mencionado no seguinte feedback? Responda apenas com o nome do produto: {feedback}")
chain_produto = prompt_produto | chat | parser

# %% [markdown]
# ### Usaremos o `RunnablePassthrough` para gerenciar as entradas e saídas e combinaremos tudo em uma única `Runnable`.

# %%
def gerar_recomendacao(sentimento: str) -> str:
    """Função Python que gera uma recomendação de resposta com base no sentimento."""
    if sentimento.lower() == "positivo":
        return "Responda com gratidão e ofereça um cupom de desconto."
    elif sentimento.lower() == "negativo":
        return "Responda com empatia, peça desculpas e ofereça suporte imediato."
    else:
        return "Agradeça o feedback e peça mais detalhes sobre a experiência."

# A função Python é agora parte da nossa cadeia
runnable_recomendacao = RunnablePassthrough.assign(
    recomendacao=lambda x: gerar_recomendacao(x['sentimento'])
)

# %% [markdown]
# ### A cadeia completa que orquestra todo o processo
# 1. Recebe o 'feedback'.
# 2. Usa RunnablePassthrough.assign para chamar as duas sub-cadeias em paralelo.
# 3. A saída é um dicionário com 'sentimento' e 'produto'.
# 4. A saída é passada para a próxima etapa, que é a nossa função Python.
# 5. A função adiciona a chave 'recomendacao' ao dicionário.

# %%
cadeia_completa = (
    RunnablePassthrough.assign(
        sentimento=chain_sentimento,
        produto=chain_produto,
    )
    | runnable_recomendacao
)

print(cadeia_completa)
# Out:
# first=RunnableAssign(mapper={
#   sentimento: ChatPromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, template="Analise o seguinte feedback e diga se o sentimento é 'positivo', 'negativo' ou 'neutro': {feedback}"), additional_kwargs={})])
#               | ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x00000229EF4BB620>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000229EF8101A0>, root_client=<openai.OpenAI object at 0x00000229EF002BA0>, root_async_client=<openai.AsyncOpenAI object at 0x00000229EF4BBE00>, model_name='gpt-oss-120b:free', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://openrouter.ai/api/v1', openai_proxy=None)
#               | StrOutputParser(),
#   produto: ChatPromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['feedback'], input_types={}, partial_variables={}, template='Qual o nome do produto mencionado no seguinte feedback? Responda apenas com o nome do produto: {feedback}'), additional_kwargs={})])
#            | ChatOpenAI(output_version=None, client=<openai.resources.chat.completions.completions.Completions object at 0x00000229EF4BB620>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000229EF8101A0>, root_client=<openai.OpenAI object at 0x00000229EF002BA0>, root_async_client=<openai.AsyncOpenAI object at 0x00000229EF4BBE00>, model_name='gpt-oss-120b:free', temperature=0.7, model_kwargs={}, openai_api_key=SecretStr('**********'), openai_api_base='https://openrouter.ai/api/v1', openai_proxy=None)
#            | StrOutputParser()
# }) middle=[] last=RunnableAssign(mapper={
#   recomendacao: RunnableLambda(lambda x: gerar_recomendacao(x['sentimento']))
# })

# %%
feedback_positivo = "Adorei o novo smartphone XPTO. A câmera é incrível e o desempenho é excelente!"
print("--- Análise de Feedback Positivo ---")
resultado_positivo = cadeia_completa.invoke({"feedback": feedback_positivo})
# Out:
# --- Análise de Feedback Positivo ---

# %%
print(f"Sentimento: {resultado_positivo['sentimento']}")
print(f"Produto: {resultado_positivo['produto']}")
print(f"Recomendação de Resposta: {resultado_positivo['recomendacao']}")
print(resultado_positivo)
# Out:
# Sentimento: Positivo
# Produto: XPTO
# Recomendação de Resposta: Responda com gratidão e ofereça um cupom de desconto.
# {'feedback': 'Adorei o novo smartphone XPTO. A câmera é incrível e o desempenho é excelente!', 'sentimento': 'Positivo', 'produto': 'XPTO', 'recomendacao': 'Responda com gratidão e ofereça um cupom de desconto.'}

# %%
# Exemplo 2: Feedback Negativo
feedback_negativo = "O fone de ouvido 'EarSonic' é péssimo. A bateria acaba em 2 horas e a conexão Bluetooth vive caindo."
print("\n--- Análise de Feedback Negativo ---")
resultado_negativo = cadeia_completa.invoke({"feedback": feedback_negativo})
# Out:
# --- Análise de Feedback Negativo ---

# %%
print(f"Sentimento: {resultado_negativo['sentimento']}")
print(f"Produto: {resultado_negativo['produto']}")
print(f"Recomendação de Resposta: {resultado_negativo['recomendacao']}")
print(resultado_negativo)
# Out:
# Sentimento: Negativo
# Produto: EarSonic
# Recomendação de Resposta: Responda com empatia, peça desculpas e ofereça suporte imediato.
# {'feedback': "O fone de ouvido 'EarSonic' é péssimo. A bateria acaba em 2 horas e a conexão Bluetooth vive caindo.", 'sentimento': 'Negativo', 'produto': 'EarSonic', 'recomendacao': 'Responda com empatia, peça desculpas e ofereça suporte imediato.'}
