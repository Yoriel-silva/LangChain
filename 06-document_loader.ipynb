# %%
from langchain_community.document_loaders.pdf import PyPDFLoader

arquivo = "files/apostila.pdf"
loader = PyPDFLoader(arquivo)
documentos = loader.load()
# Out:
# C:\Users\Micro\AppData\Local\Temp\ipykernel_14356\401533692.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders.pdf import PyPDFLoader

# %%
len(documentos)
# Out:
# 28

# %%
documentos[0]
# Out:
# Document(metadata={'producer': 'Microsoft® Word 2013', 'creator': 'Microsoft® Word 2013', 'creationdate': '2016-05-04T10:06:39-03:00', 'author': 'lucas', 'moddate': '2016-05-04T10:06:39-03:00', 'source': 'files/apostila.pdf', 'total_pages': 28, 'page': 0, 'page_label': '1'}, page_content='INTRODUÇÃO À PROGRAMAÇÃO \nCOM PYTHON \n \n \n \n \n \n \n \nPrograma de Educação Tutorial \nGrupo PET - ADS   \nIFSP -  Câmpus São Carlos')

# %%
documentos[5].page_content
# Out:
# '3 \n \n2. Digite o comando sudo apt-get install python3.4 no terminal do GNU/Linux para inicializar \no processo de instalação. \n \n \n \n3. Terminado o download, o interpretador já estará instalado no computador. \n \n \n \n \nb) Instalação do IDLE no Linux \n \nO IDLE é um ambiente in tegrado de desenvolvimento que acompanha a instalação do interpretador \nPython em sistemas operacionais Windows. Para tê -lo disponível em distribuições Linux basta \nseguir as etapas abaixo: \n \n1. Acesse o terminal Linux. \n \n \n \n2. Digite o comando sudo apt-get install idle-python3.4. \n \n \n \n3. Para executá-lo basta digitar no terminal idle-python3.4 &.'

# %%
from langchain_openai.chat_models import ChatOpenAI
import os
from dotenv import load_dotenv

# Carregar variáveis de ambiente
load_dotenv()
chat = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key = os.getenv("ROUTER_API"),
    model="gpt-oss-120b:free", 
    temperature=0.7
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from langchain_openai.chat_models import ChatOpenAI
#       2 import os
#       3 from dotenv import load_dotenv
#       4
#
# File c:\ProjetosIA\LangChain\.venv\Lib\site-packages\langchain_openai\__init__.py:1
# ----> 1 from langchain_openai.chat_models import (
#       2     AzureChatOpenAI,
#       3     ChatOpenAI,
#       4 )
#       5 from langchain_openai.embeddings import (
#       6     AzureOpenAIEmbeddings,
#       7     OpenAIEmbeddings,
#       8 )
#       9 from langchain_openai.llms import AzureOpenAI, OpenAI
#
# File c:\ProjetosIA\LangChain\.venv\Lib\site-packages\langchain_openai\chat_models\__init__.py:1
# ----> 1 from langchain_openai.chat_models.azure import AzureChatOpenAI
#       2 from langchain_openai.chat_models.base import ChatOpenAI
#       4 __all__ = [
# ...

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

# Prompt (com documento + pergunta)
prompt = ChatPromptTemplate.from_template("""
Responda usando o documento abaixo.

Documento:
{context}

Pergunta:
{question}
""")

# Pipeline LCEL
chain = prompt | chat | StrOutputParser()

# Invoke com documento + pergunta
resposta = chain.invoke({
    "context": documentos,
    "question": "Do que se trata esse documento?"
})

print(resposta)
# Out:
# O documento é uma apostila de **Introdução à Programação com Python**. Ele reúne o conteúdo didático de um curso de extensão do Programa de Educação Tutorial (PET‑ADS) do IFSP São Carlos, abordando os conceitos básicos da linguagem Python – instalação, variáveis, strings, números, listas, tuplas, dicionários, bibliotecas, estruturas de decisão e de repetição, funções, além de exercícios práticos e respostas. Em suma, trata‑se de um material de apoio para iniciantes aprenderem a programar em Python.

# %% [markdown]
# ### Carregamento Arquivo CSV

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

arquivo = "files/imdb_movies.csv"
loader = CSVLoader(arquivo)
documentos = loader.load()

# %%
documentos[5]
# Out:
# Document(metadata={'source': 'files/imdb_movies.csv', 'row': 5}, page_content=': 5\nMovie Name: The Godfather: Part II\nYear of Release: (1974)\nWatch Time: 202 min\nMovie Rating: 9.0\nMeatscore of movie: 90\nVotes: 34,709\nGross: $57.30M\nDescription: The early life and career of Vito Corleone in 1920s New York City is portrayed, while his son, Michael, expands and tightens his grip on the family crime syndicate.')

# %%
len(documentos)
# Out:
# 1000

# %%
documentos[80].metadata
# Out:
# {'source': 'files/imdb_movies.csv', 'row': 80}

# %%
pergunta = "Qual filme com menor e maior metascore baseado no documento?"

# Invoke com documento + pergunta
resposta = chain.invoke({
    "context": documentos,
    "question": pergunta,
})

print(resposta)

# %% [markdown]
# ### Web via URL

# %%
from langchain_community.document_loaders import WebBaseLoader
url = "https://medium.com/ensina-ai/introdu%C3%A7%C3%A3o-a-processamento-de-linguagem-natural-174936c096b"
loader = WebBaseLoader(url)
documents = loader.load()

# %%
len(documents)
# Out:
# 1

# %%
documents[0].page_content[:500]
# Out:
# 'Just a moment...Enable JavaScript and cookies to continue'
