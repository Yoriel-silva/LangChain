# %%
from langchain_openai import OpenAIEmbeddings
import os
from dotenv import load_dotenv

load_dotenv()

embedding_model = OpenAIEmbeddings(
    api_key = os.getenv("OPENAI_API_KEY"),
    model="text-embedding-3-small", 
)

# %%
embeddings = embedding_model.embed_documents(
    [
        "Eu gosto de cachorro",
        "Eu gosto de animais",
        "Hoje a tarde está chovendo"
    ]
)

# %%
len(embeddings)
# Out:
# 3

# %%
embeddings[0][:10]
# Out:
# [0.014892578125,
#  -0.03369140625,
#  -0.036956787109375,
#  0.02862548828125,
#  0.008209228515625,
#  0.006954193115234375,
#  0.022613525390625,
#  0.030792236328125,
#  -0.055816650390625,
#  -0.037811279296875]

# %%
len(embeddings[0])
# Out:
# 1536

# %%
import numpy as np

np.dot(embeddings[0], embeddings[1])
# Out:
# np.float64(0.7640207439111748)

# %%
import numpy as np

np.dot(embeddings[0], embeddings[2])
# Out:
# np.float64(0.2761761744883984)

# %%
import numpy as np

np.dot(embeddings[1], embeddings[2])
# Out:
# np.float64(0.27805175593471176)

# %%
for i in range(len(embeddings)):
    for j in range(len(embeddings)):
        print(round(np.dot(embeddings[i], embeddings[j]), 2), end=" | ")
    print()
# Out:
# 1.0 | 0.76 | 0.28 |
# 0.76 | 1.0 | 0.28 |
# 0.28 | 0.28 | 1.0 |

# %%
pergunta = "O que é um cachorro?"
emb_query = embedding_model.embed_query(pergunta)
emb_query[:10]
# Out:
# [0.036346435546875,
#  -0.0241546630859375,
#  -0.0258636474609375,
#  0.0460205078125,
#  0.0255889892578125,
#  -0.002040863037109375,
#  0.006404876708984375,
#  -0.01238250732421875,
#  -0.004001617431640625,
#  -0.00194549560546875]
